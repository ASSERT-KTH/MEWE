# %% [markdown]
# ## POP name: bma

# %%
from reports.plot_precision_time import plot_times_for
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12))

plot_times_for(["bma", "bog"], w=20, use_test_name=False,  diff_home=True)

# %% [markdown]
# There is a clear difference between times larger than 0.01s.
#
# Zooming the interval betweem 0 and 0.001s

# %%
plt.figure(figsize=(12,12))
plot_times_for(["bma", "bog"], diff_home=False, subplot=17, w = 20, use_test_name=False)

# %% [markdown]
# The distribution substracting the home times is the same.

# %%
plt.figure(figsize=(12,12))
plot_times_for(["bma", "bog"], diff_home=True, subplot=15, w = 25, use_test_name=False)

# %%
plot_times_for(["bma", "bog"], diff_home=True, subplot=7, w = 25, use_test_name=False)

# %%
from reports.plot_precision_time import plot_scatter_times_for

plot_scatter_times_for("bog")
