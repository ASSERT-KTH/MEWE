# %%
from reports.plot_precision_time import plot_times_for
from common.common import *

plot_times_for("bma")
# Out:
# --------------------------------------------
# OperationalErrorTraceback (most recent call last)
# ~/Documents/Develop/fastly4edge/speedTest/python_scripts/fastly4edge/lib/python3.7/site-packages/peewee.py in connect(self, reuse_if_open)
#    3064             with __exception_wrapper__:
# -> 3065                 self._state.set_connection(self._connect())
#    3066                 if self.server_version is None:
#
# ~/Documents/Develop/fastly4edge/speedTest/python_scripts/fastly4edge/lib/python3.7/site-packages/peewee.py in _connect(self)
#    3401         conn = sqlite3.connect(self.database, timeout=self._timeout,
# -> 3402                                isolation_level=None, **self.connect_params)
#    3403         try:
#
# OperationalError: unable to open database file
#
# During handling of the above exception, another exception occurred:
#
# OperationalErrorTraceback (most recent call last)
# ...
